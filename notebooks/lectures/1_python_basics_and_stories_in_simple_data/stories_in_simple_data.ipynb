# %% [markdown]
# # Thinking about _stories_ in simple data

# %%
*

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Two data points

# %%
x=['A','B']
y=[105, 302]

# %%
plt.plot(x,y, 'o')

# %%
plt.plot(x,y, 'o')
plt.xlabel('TIME')
plt.ylabel('POLUTION')
# Out:
# Text(0,0.5,'POLUTION')

# %%
x2=['A','B', 'C']
y2=[105, 511, 302]

# %%
plt.plot(x2,y2, 'o')

# %%
plt.plot(x2,y2, 'o-')
